# %%
from training_simulator import main

# %%
pipe, scores, keep, X_train, y_train = main()
# Out:
# 2025-07-16 15:57:11,165                     - INFO - Parsing Args >>>
# 2025-07-16 15:57:11,165                     - INFO - -------Given Args-------:
#                  pass_validation = False
#                  base_line = 69
#                  data_container = 'retraining-data'
#                  store_model = True
#                  select_latest_data = False
# ------------------------------------
# 2025-07-16 15:57:11,165                     - INFO - Provisioning Data >>>
# 2025-07-16 15:57:11,165                     - INFO - No environment configuration found.
# 2025-07-16 15:57:11,165                     - INFO - ManagedIdentityCredential will use IMDS
# 2025-07-16 15:57:11,165                     - INFO - Getting defined client customer_churn.csv>>>
# 2025-07-16 15:57:11,165                     - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
# ...

# %%
X_train.drop_duplicates(inplace=True)
# Out:
# Index(['Age', 'Gender', 'Tenure', 'Usage Frequency', 'Support Calls',
#        'Payment Delay', 'Subscription Type', 'Contract Length', 'Total Spend',
#        'Last Interaction'],
#       dtype='object')

# %%
import requests

url = "https://prod-20.northcentralus.logic.azure.com:443/workflows/297542e75c3d439d9c7c0ed19418424e/triggers/When_a_HTTP_request_is_received/paths/invoke?api-version=2016-10-01&sp=%2Ftriggers%2FWhen_a_HTTP_request_is_received%2Frun&sv=1.0&sig=ld_1JlFuje2QQZIGD40xNFHmZE7adLiVTTvxaEJr8jE"

data = {
    "to": "manojcolan18@gmail.com",
    "subject": "⚠️ Model Drift Alert",
    "body": "The model's accuracy dropped to 0.71. Action required."
}

res = requests.post(url, json=data)
print(res.status_code, res.text)
# Out:
# 202

# %%
model, xtrain, ytrain = main()
# Out:
# 2025-07-15 15:21:46,263                     - INFO - Parsing Args >>>
# 2025-07-15 15:21:46,263                     - INFO - -------Given Args-------:
#                  pass_validation = False
#                  base_line = 69
#                  data_container = 'retraining-data'
#                  store_model = True
#                  select_latest_data = False
# ------------------------------------
# 2025-07-15 15:21:46,263                     - INFO - Provisioning Data >>>
# 2025-07-15 15:21:46,263                     - INFO - No environment configuration found.
# 2025-07-15 15:21:46,263                     - INFO - ManagedIdentityCredential will use IMDS
# 2025-07-15 15:21:46,263                     - INFO - Getting defined client customer_churn.csv>>>
# 2025-07-15 15:21:46,263                     - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
# ...

# %%
from detect_drift_get_features_to_handle import detect_save_extract_drift, get_features_to_handle

score_by_column , stats = detect_save_extract_drift("churnprediction1", "training-data", "retraining-data")
# Out:
# 2025-07-15 15:26:00,730                     - INFO - Loading current and reference data...
# 2025-07-15 15:26:00,731                     - INFO - No environment configuration found.
# 2025-07-15 15:26:00,731                     - INFO - ManagedIdentityCredential will use IMDS
# 2025-07-15 15:26:00,733                     - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.23.0 Python/3.11.0 (Windows-10-10.0.19045-SP0)'
# No body was attached to the request
# 2025-07-15 15:26:02,647                     - INFO - DefaultAzureCredential acquired a token from AzureCliCredential
# 2025-07-15 15:26:02,647                     - INFO - Request URL: 'https://churnprediction1.blob.core.windows.net/training-data?restype=REDACTED&comp=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-version': 'REDACTED'
# ...

# %%
import pandas as pd

df = pd.read_csv(r"D:\Azure MLOps learning\Custom project\customer churn prediction\pracitce\Alldatasets\customer_churn2.csv")
features_to_handle = get_features_to_handle(model.named_steps['Train'], xtrain, ytrain, score_by_column, df)
# Out:
# 2025-07-15 15:29:43,299                     - INFO - Getting the feature importance score....
# 2025-07-15 15:29:43,328                     - INFO - Given model tree based...
# 2025-07-15 15:29:43,348                     - INFO - Collecting features with significant drift....
# 2025-07-15 15:29:43,349                     - INFO - Getting columns to be handled...

# %%
9500-5500
# Out:
# 4000

# %%
from column_transforms_drift_data import get_drift_handling_pipeline

# %%
drift_handler = get_drift_handling_pipeline(features_to_handle)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# %%
model_pipe = Pipeline(
    steps=[
        ("Preprocess", get_drift_handling_pipeline(features_to_handle)), 
        ("Model", RandomForestClassifier())
    ]
)

# %%
df.drop(columns=['Churn'], axis=0)
# Out:
#       CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0          28257   33    Male      19               13              5
# 1          34183   21  Female       9               12              4
# 2          14372   43    Male      20               18              2
# 3          22769   24  Female      30               12              5
# 4          25933   29  Female       5                2              0
# ...          ...  ...     ...     ...              ...            ...
# 7111       17925   50  Female      17                5              8
# 7112       60891   65  Female      15                2              9
# 7113       54613   57  Female      55                5              8
# 7114       62249   63    Male      53                6              8
# 7115       37502   62  Female      55                1             10
#
#       Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =  train_test_split(df.drop(columns=['Churn']), df['Churn'], test_size=0.2)

# %%
model_pipe.cop
# Out:
# Pipeline(steps=[('Preprocess',
#                  Pipeline(steps=[('continuous',
#                                   ContinuousTransformer(features=[])),
#                                  ('discrete',
#                                   DiscreteTransformer(features=['CustomerID',
#                                                                 'Age', 'Tenure',
#                                                                 'Usage '
#                                                                 'Frequency',
#                                                                 'Support Calls',
#                                                                 'Payment Delay',
#                                                                 'Total Spend',
#                                                                 'Last '
#                                                                 'Interaction'])),
#                                  ('categorical',
# ...

# %%
model_pipe.fit(x_train, y_train)
# Out:
# 2025-07-15 15:40:27,630                     - INFO - Handling Continuous features....Total 0
# 2025-07-15 15:40:27,631                     - INFO - Handling Discrete features....Total 8
# 2025-07-15 15:40:27,632                     - INFO - Binning CustomerID into 10 bins
# 2025-07-15 15:40:27,633                     - INFO - Binning Age into 9 bins
# 2025-07-15 15:40:27,635                     - INFO - Binning Tenure into 10 bins
# 2025-07-15 15:40:27,637                     - INFO - Binning Usage Frequency into 6 bins
# 2025-07-15 15:40:27,638                     - INFO - Binning Support Calls into 2 bins
# 2025-07-15 15:40:27,639                     - INFO - Binning Payment Delay into 6 bins
# 2025-07-15 15:40:27,641                     - INFO - Binning Total Spend into 10 bins
# 2025-07-15 15:40:27,643                     - INFO - Binning Last Interaction into 6 bins
# 2025-07-15 15:40:27,646                     - INFO - Handling Categorical features....Total 3
# ...

# %%
model.predict(df2.drop(columns=['Churn']))
# Out:
# array([1, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
df2
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
import pickle

# %%
with open("testingmodel.pkl", "wb") as file: 
    pickle.dump(model, file)

# %%
import joblib

model_loaded = joblib.load(r"testingmodel.pkl")

# %%
model_loaded.predict(df2.drop(columns=['Churn']))
# Out:
# array([1, 0, 0, ..., 1, 1, 1], dtype=int64)
